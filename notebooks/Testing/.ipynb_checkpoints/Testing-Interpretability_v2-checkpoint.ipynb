# %%
import numpy as np
import torch
import torch.nn as nn
from IPython.display import display, HTML
from transformers import DistilBertModel, DistilBertTokenizer,logging
import matplotlib
import matplotlib.pyplot as plt
from captum.attr import visualization as viz
from captum.attr import IntegratedGradients, LayerConductance, LayerIntegratedGradients
from captum.attr import configure_interpretable_embedding_layer, remove_interpretable_embedding_layer
from captum.attr import Occlusion
import time
import pickle
from tqdm import tqdm
import spacy
from spacy import displacy
import seaborn as sns
import pandas as pd
import numpy as np
import collections

nlp = spacy.load('en_core_web_trf')
logging.set_verbosity_error()
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# # Load model and set seed

# %%
# Bert mode
bert = DistilBertModel.from_pretrained('distilbert-base-uncased')

class BERT(nn.Module):
    def __init__(self, bert):
        
        super(BERT, self).__init__()
        
        # Distil Bert model
        self.bert = bert
        ## Additional layers
        # Dropout layer
        self.dropout = nn.Dropout(0.3)
        # Relu 
        self.relu =  nn.ReLU()
        # Linear I 
        self.fc1 = nn.Linear(768, 512)
        # Linear II (Out)
        #self.fc2 = nn.Linear(512, 170)
        self.fc2 = nn.Linear(512, 817)

        
        # Softmax
        self.softmax = nn.LogSoftmax(dim=1)


    # Forward pass
    def forward(self, **kwargs):

        # Pass data trough bert and extract 
        cls_hs = self.bert(**kwargs)
        # Extract hidden state
        hidden_state = cls_hs.last_hidden_state
        # Only first is needed for classification
        pooler = hidden_state[:, 0]
        
        # Dense layer 1        
        x = self.fc1(pooler)
        # ReLU activation
        x = self.relu(x)
        # Drop out
        x = self.dropout(x)
        # Dense layer 2
        x = self.fc2(x)
        # Activation
        x = self.softmax(x)

        return x
    
# Load the entire model
model = BERT(bert)

# Load trained model (colab)
try:
    try:
        model_save_name = 'saved_weights_PartialDescriptions817.pt'
        path = F"/content/gdrive/My Drive/{model_save_name}"
        model.load_state_dict(torch.load(path))
        print('Google Success')

    except:
        model_save_name = 'saved_weights_PartialDescriptions817.pt'
        path = "../models/" + model_save_name
        model.load_state_dict(torch.load(path, 
                                         map_location=torch.device('cpu')))
        print('Local Success')
except:
    print('No pretrained model found.')
    
model.to(device)
model.eval()
model.zero_grad()
# Out:
# Local Success

# %%
# Set seeds
torch.manual_seed(333)
np.random.seed(333)

# %% [markdown]
# ### Function and tokens

# %%
ref_token_id = tokenizer.pad_token_id # A token used for generating token reference
sep_token_id = tokenizer.sep_token_id # A token used as a separator between question and text and it is also added to the end of the text.
cls_token_id = tokenizer.cls_token_id # A token used for prepending to the concatenated question-text word sequence

# %%
# Modify the prediction output and define a custom forward
def predict(inputs):
    return model(input_ids=inputs, attention_mask=attention_mask)[0]
def custom_forward(inputs):
    preds = predict(inputs)
    return torch.exp(preds)

# %%
# Tokenize functions
def construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id):

    text_ids = tokenizer.encode(text, add_special_tokens=False)
    # construct input token ids
    input_ids = [cls_token_id] + text_ids + [sep_token_id]
    # construct reference token ids 
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(text_ids) + [sep_token_id]

    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(text_ids)

def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)# * -1
    return token_type_ids, ref_token_type_ids

def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids
    
def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)

# %%
# Summarize and vis functions
def summarize_attributions_ig(attributions):
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    return attributions

def summarize_attributions_occ(attributions):
    return attributions.sum(axis=0)

def token_to_words(attribution, tokens):
    
    words = []
    attributes = []

    for attribute, word in zip(attribution, tokens):

        attribute = attribute.cpu().detach().numpy()
        if word == '[CLS]' or word == '[SEP]':
            words.append(word)
            attributes.append([attribute])
        elif not word.startswith('##'):
            words.append(word)
            attributes.append([attribute])
        elif word.startswith('##'):
            words[-1] += word.strip('##')
            attributes[-1] = np.append(attributes[-1], attribute)

    attribution = [np.sum(mean) for mean in attributes]
    return attribution, words

def colorize(attribution, tokens):
    
    template = """  
    <mark class="entity" style="
    background: {}; 
    padding: 0.4em 0.0em; 
    margin: 0.0em; 
    line-height: 2; 
    border-radius: 0.0em;
    ">{}<span style="
    font-size: 0.8em; 
    font-weight: bold; 
    line-height: 1; 
    border-radius: 0.0em;   
    text-align-last:center;
    vertical-align: middle;
    margin-left: 0rem;
    "></span></mark>
    """

    colored_string = ''
    normalized_and_mapped = matplotlib.cm.ScalarMappable(cmap=matplotlib.cm.PiYG).to_rgba(attribution)
    for idx, (word, color) in enumerate(zip(tokens, normalized_and_mapped)):
        
        word = word + ' '
        color = matplotlib.colors.rgb2hex(color[:3])
        if word.strip() == '[CLS]' or word.strip() == '[SEP]':
            color = '#ffffff'
        #print(color)
        colored_string += template.format(color, word)

    return colored_string

# %%
lig = LayerIntegratedGradients(custom_forward, model.bert.embeddings)
occ = Occlusion(custom_forward)

# %% [markdown]
# ## Single Example

# %%
text = 'The plant has a purple flower with white petals.'

# %%
input_ids, ref_input_ids, sep_id = construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id)
token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, sep_id)
position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
attention_mask = construct_attention_mask(input_ids)

indices = input_ids[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)

# %%
attributions_ig = lig.attribute(inputs=input_ids,
                                baselines=ref_input_ids,
                                n_steps=20,
                                internal_batch_size=1,
                                return_convergence_delta=False)

attribution_occ = occ.attribute(inputs=input_ids, 
                                sliding_window_shapes=tuple([1,]), 
                                strides=None, 
                                baselines=None, 
                                target=None, 
                                additional_forward_args=None, 
                                perturbations_per_eval=1, 
                                show_progress=False)

# %%
# Sum the matrices
attributions_ig_sum = summarize_attributions_ig(attributions_ig)
attributions_occ_sum = summarize_attributions_occ(attribution_occ)

# %%
# Token to words
# Words are the same in this case
attributions_ig_words, words = token_to_words(attributions_ig_sum, all_tokens)
attributions_occ_words, words = token_to_words(attributions_occ_sum, all_tokens)

# %%
# IG
string = colorize(attributions_ig_words, words)
display(HTML(string))
# OCC
string = colorize(attributions_occ_words, words)
display(HTML(string))
# Out:
#
#     <mark class="entity" style="
#     background: #ffffff;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">[CLS] <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faeaf2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">the <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plant <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #edf6df;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">has <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">a <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7f6f7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">purple <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e8f5d5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">flower <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e2f3ca;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #77b53c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">white <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #93c959;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">petals <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7cbe4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ffffff;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">[SEP] <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ffffff;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">[CLS] <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #509423;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">the <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plant <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faedf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">has <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e388ba;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">a <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #66a731;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">purple <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eff6e4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">flower <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eff6e5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">white <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7bb93e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">petals <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #43861f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ffffff;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">[SEP] <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>

# %% [markdown]
# ## Loop

# %%
def extract_PoS(text):
    
    global attention_mask
    
    input_ids, ref_input_ids, sep_id = construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id)
    token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, sep_id)
    position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
    attention_mask = construct_attention_mask(input_ids)
    

    indices = input_ids[0].detach().tolist()
    all_tokens = tokenizer.convert_ids_to_tokens(indices)
    
    
    attributions_ig = lig.attribute(inputs=input_ids,
                                    baselines=ref_input_ids,
                                    n_steps=20,
                                    internal_batch_size=1,
                                    return_convergence_delta=False)

    attributions_occ = occ.attribute(inputs=input_ids, 
                                    sliding_window_shapes=tuple([1,]), 
                                    strides=None, 
                                    baselines=None, 
                                    target=None, 
                                    additional_forward_args=None, 
                                    perturbations_per_eval=1, 
                                    show_progress=False)
    
    # Sum the matrices
    attributions_ig_sum = summarize_attributions_ig(attributions_ig)
    attributions_occ_sum = summarize_attributions_occ(attributions_occ)
    
    attributions_ig_words, words = token_to_words(attributions_ig_sum, all_tokens)
    attributions_occ_words, words = token_to_words(attributions_occ_sum, all_tokens)
    
    # NLP (Skip tokens)
    doc = nlp(' '.join(words[1:-1]))

    PoS = []
    
    #print(doc)
    
    for token, ig_att, occ_att in zip(doc, attributions_ig_words[1:-1], attributions_occ_words[1:-1]):
        #print(f'{token.text} -- {token.pos_} -- {ig_att} -- {occ_att}')
        
        PoS.append((token.lemma_, token.pos_, ig_att, occ_att))
        # Totals for visualization
        #PoS_totals[token.pos_].append(attribution)
    
    return PoS
    # Sort on attribution    
    #PoS.sort(key = lambda x : (-x[2]))

        #PoS_list['Sorghum arundinaceum'].append(PoS)

# %%
#extract_PoS(text)

# %%
text_list = ['The plant is purple.',
             'The species has a spiky stem and has spikets on the bark',
             'The stem is brownish with grey spikelets.',
             'The leaves are green with an orange glow at the tips.']

# %%
datadict = pickle.load(open('../data/description/04_TRAIN_0-817_PLANTS.pkl', 'rb'))
text_list = [data for data in datadict['Muhlenbergia ligularis']]

# %%
Pos_list = [extract_PoS(text) for text in tqdm(text_list)]
# Out:
# 100%|█████████████████████████████████████████| 153/153 [18:17<00:00,  7.17s/it]

# %%
Pos_list[0]
# Out:
# [('panicle', 'NOUN', -0.3906442905954996, 3.4940263e-07),
#  ('2a6', 'NUM', 0.06981400772440272, 1.6016617e-07),
#  ('cm', 'NOUN', -0.2605749676823786, 2.9087687e-08),
#  ('long', 'ADJ', 0.11999430726130392, 6.5758684e-08),
#  (',', 'PUNCT', 0.21911153716079546, 1.1654148e-07),
#  ('0', 'NUM', 0.05613548507915143, 7.339939e-08),
#  ('.', 'SYM', -0.3102448257199982, 1.5860653e-07),
#  ('5a1', 'NUM', 0.1252425322404876, 2.1808374e-07),
#  ('.', 'PUNCT', -0.0011190393660574073, 1.9116168e-08),
#  ('2', 'NUM', 0.09935384594734732, 1.7046236e-07),
#  ('cm', 'NOUN', -0.1622523969307499, 1.8552423e-07),
#  ('wide', 'ADJ', -0.1829667550056739, 2.177596e-07),
#  (',', 'PUNCT', 0.09562595516868565, -2.779197e-08),
#  ('open', 'ADJ', -0.15160560151872465, 9.275128e-08),
#  (',', 'PUNCT', 0.051809792222765265, 5.2124506e-08),
#  ('loosely', 'ADV', 0.017183918498176968, 1.7444006e-07),
#  ('-', 'PUNCT', 0.18551442700341997, 3.1638606e-07),
#  ('flowered', 'ADJ', 0.309475307392882, 2.1350914e-07),
#  (',', 'PUNCT', 0.17107422986632445, 2.3800203e-07),
#  ('primary', 'ADJ', 0.08750498073141043, 1.22112e-07),
#  ('branch', 'NOUN', -0.006829615482165056, -7.064216e-10),
#  ('0', 'NUM', -0.16407305749912932, 1.6706889e-07),
#  ('.', 'NUM', -0.10173551355499572, 6.470876e-08),
#  ('2a0', 'NUM', -0.03691315634070147, 1.3379059e-07),
#  ('.', 'NUM', -0.06566692134947376, 2.5667256e-07),
#  ('6', 'NUM', 0.02372402312973026, 6.123882e-08),
#  ('mm', 'NOUN', -0.17703811620427642, 1.6685416e-07),
#  ('long', 'ADJ', 0.12405169802928902, 2.847628e-08),
#  (',', 'PUNCT', 0.15577635697895295, 2.4216723e-07),
#  ('exclude', 'VERB', -0.08717217473903256, 1.9336983e-07),
#  ('the', 'DET', 0.16181685869317608, -7.365077e-08),
#  ('awn', 'NOUN', 0.5007889342188827, 2.1906999e-07),
#  (',', 'PUNCT', 0.09578334455543792, 2.039364e-07),
#  ('one', 'NUM', -0.04070733780151205, 1.5857033e-07),
#  ('per', 'ADP', -0.08679164290900292, 7.316618e-08),
#  ('node', 'NOUN', 0.010708293854782388, 7.4986374e-08),
#  (',', 'PUNCT', 0.09716039493660329, 1.4475498e-07),
#  ('racemosely', 'ADV', 0.14340840889989856, 1.9582353e-07),
#  ('insert', 'VERB', -0.014437787967865543, 2.2707823e-07),
#  ('.', 'PUNCT', 0.18955615713378832, 1.2899137e-07)]

# %%
for sentence in Pos_list[10:20]:
    words = [item[0] for item in sentence]
    attribution_integrads = [item[2] for item in sentence]
    attribution_occlus = [item[3] for item in sentence]
    string = colorize(attribution_integrads, words)
    display(HTML(string))
    string = colorize(attribution_occlus, words)
    display(HTML(string))
    print('\n')
# Out:
#
#     <mark class="entity" style="
#     background: #77b53c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">perennial <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #bde38d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #bde38d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">intricately <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #77b53c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">branch <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">near <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e99cc8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">base <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">perennial <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c41a7c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">intricately <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #6dad36;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">branch <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fad4e9;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">near <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e4f4cd;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">base <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7bb93e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f9d3e8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">caryopsis <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a1d26a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f8f4f6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">adherent <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eeadd4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">pericarp <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">fusiform <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a7d672;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">caryopsis <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e6f5d0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f2f6ec;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">adherent <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eeadd4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">pericarp <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #43861f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">fusiform <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #60a22d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d0ecad;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">trichochloa <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">consist <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #67a832;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">of <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #67a832;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">robust <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #91c857;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">perennial <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #66a731;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">up <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7bb93e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">to <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3f811e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">metre <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #9acd61;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">tall <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cfebaa;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #529624;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">compressed <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #66a731;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #589b28;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">keeled <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #66a731;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">or <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #69aa33;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">rounded <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a7d672;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">basal <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #83bf46;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">sheath <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #498d20;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5ea02c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">1 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8cc551;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left:
#
#     <mark class="entity" style="
#     background: #db6ca8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">trichochloa <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c9e8a2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">consist <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #40831e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">of <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #43861f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">robust <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c4e699;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">perennial <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #42841f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">up <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b0dc7d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">to <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a3d36c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a5d56f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">metre <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a5d56f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">tall <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #6bac34;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #4b8f21;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">compressed <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #549825;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7f7f7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">keeled <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #43861f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">or <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #98cc5f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">rounded <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cdeaa7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">basal <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a9d874;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">sheath <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #34741c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3d7f1e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">1 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #40831e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left:
#
#     <mark class="entity" style="
#     background: #e9f5d8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">caryopses <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e795c3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">1 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ea9fca;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">7a2 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b71472;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d24c97;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">5 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fddeee;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">mm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e58dbe;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">long <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #da69a6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">fusiform <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d4539b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e286b8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">reddish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f4c1df;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fad4e9;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">brown <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f0b2d7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">caryopses <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e795c3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">1 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f3f7ef;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">7a2 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f2badc;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b9e187;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">5 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ce3d8f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">mm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c01879;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">long <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #529624;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3a7b1d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">fusiform <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #bb1675;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #9ed067;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">reddish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #6dad36;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faedf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">brown <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cbe9a4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">panicle <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faecf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">10a35 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #95cb5c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">cm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c6e79c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">long <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7bb93e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ecf6de;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3a5 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b2dd7f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">cm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5ea02c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">wide <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #bbe28a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">loosely <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #4e9322;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">contract <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d0ecad;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">to <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #6faf37;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">open <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #60a22d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3c7d1d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">lax <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #86c049;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #4e9322;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">reddish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7bb93e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #31711b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">purple <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #79b73d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #91c857;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">primary <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></
#
#     <mark class="entity" style="
#     background: #faedf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">panicle <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">10a35 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f8cee6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">cm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faecf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">long <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b5df82;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
# ...
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">clomena <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f3bdde;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">possess <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f9f1f5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">spikelet <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #dc70aa;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f8f3f6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">upper <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e7f5d3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">glume <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e7f5d2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">that <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">be <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #77b53c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7bb93e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c7e89f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">veined <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faebf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f1b7da;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">often <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cbe9a4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f5c6e2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f9eef4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">toothed <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eba3cd;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cdeaa7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">individual <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f9eff4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e6f5d0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">a <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eef6e2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">densely <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0
#
#     <mark class="entity" style="
#     background: #eeabd2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">clomena <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fce5f1;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">possess <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e1f3c7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">spikelet <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f4f7f0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f4f7f0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">upper <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #276419;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">glume <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8e0152;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">that <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b7e085;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">be <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e9f5d8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f3f6ed;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d14895;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">veined <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fde2f0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cf4191;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">often <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eff6e4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">3 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faebf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #edf6df;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">toothed <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fce5f1;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f9f0f5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">individual <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #faedf3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #9f095f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">a <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #fde0ef;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">densely <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0

# %% [markdown]
# ## Vis

# %%
flat_list = []
for idx, sublist in enumerate(Pos_list):
    for item in sublist:
        flat_list.append((idx, item[0], item[1], item[2], item[3]))

# %%
df = pd.DataFrame(flat_list, columns=['sentence', 'word', 'pos', 'ig', 'occ'])

# %%
# Scale
df['ig_scaled'] = (df['ig'] - df['ig'].mean()) / (df['ig'].max() - df['ig'].min())
df['occ_scaled'] = (df['occ'] - df['occ'].mean()) / (df['occ'].max() - df['occ'].min())

# %%
idx = []
for sentence in df['sentence'].unique():
    idx += list(df[df['sentence'] == sentence]['ig_scaled'].sort_values(ascending=False)[0:3].index)
    #idx += list(df[(df['sentence'] == sentence) & (df['pos'] == 'NOUN') | (df['pos'] == 'ADJ')]['ig_scaled'].sort_values(ascending=False)[0:3].index)
df_highest = df.iloc[idx]

df_highest_melt = df_highest.melt(id_vars=['pos'], value_vars=['ig_scaled', 'occ_scaled'])

# %%
df[(df['sentence'] == 0)]['ig_scaled'].sort_values(ascending=False)[0:3].index
# Out:
# Int64Index([31, 17, 4], dtype='int64')

# %%
#df_highest.groupby('pos').count()
df_highest
# Out:
#       sentence        word    pos        ig           occ  ig_scaled  \
# 31           0         awn   NOUN  0.500789  2.190700e-07   0.197377
# 17           0    flowered    ADJ  0.309475  2.135091e-07   0.123133
# 4            0           ,  PUNCT  0.219112  1.165415e-07   0.088065
# 46           1       glume   NOUN  0.372046 -4.040910e-07   0.147415
# 48           1      floret   NOUN  0.145314 -3.879657e-07   0.059426
# ...        ...         ...    ...       ...           ...        ...
# 4463       151           .  PUNCT  0.270937  1.932763e-08   0.108177
# 4479       151  pedicelled    ADJ  0.249216 -1.460305e-07   0.099748
# 4509       152     unawned    ADJ  0.539351  3.241565e-07   0.212342
# 4507       152      obtuse    ADJ  0.280530  4.778027e-07   0.111900
# 4502       152       lower    ADJ  0.277524  2.031424e-07   0.110734
#
#       occ_scaled
# 31      0.098965
# 17      0.096605
# 4       0.055440
# 46     -0.165577
# 48     -0.158731
# ...          ...
# 4463    0.014171
# 4479   -0.056026
# 4509    0.143576
# 4507    0.208802
# 4502    0.092204
#
# [459 rows x 7 columns]

# %%
df_melt = df.melt(id_vars=['pos'], value_vars=['ig_scaled', 'occ_scaled'])

# %%
with sns.axes_style("whitegrid"):
    f, ax = plt.subplots(figsize=(25, 16))
    ax = sns.violinplot(x="pos", y="value", hue="variable",
                        data=df_melt, 
                        palette="muted", 
                        split=False,
                        #inner="quartile",
                        bw=.2)

# %%
# Sort the values
mean_values = [(column, float(df_melt[df_melt['pos'] == column].mean())) for column in df['pos'].unique()]
mean_values.sort(key = lambda x : (x[1]))

sorter = [pos_value for (pos_value, mean) in mean_values]
#print(sorter)

# %%
df_melt_sorted = df_melt.set_index('pos')
df_melt_sorted = df_melt_sorted.loc[sorter]
df_melt_sorted['pos'] = df_melt_sorted.index

# %%
with sns.axes_style("whitegrid"):
    f, ax = plt.subplots(figsize=(15, 8))
    # Initialize the figure
    #f, ax = plt.subplots()
    sns.despine(bottom=True, left=True)

    # Show each observation with a scatterplot
    sns.stripplot(x="value", y="pos", hue="variable",
                  data=df_melt, dodge=True, alpha=.25, zorder=1)

    # Show the conditional means, aligning each pointplot in the
    # center of the strips by adjusting the width allotted to each
    # category (.8 by default) by the number of hue levels
    sns.pointplot(x="value", y="pos", hue="variable",
                  data=df_melt, dodge=.4,
                  join=False, palette="dark",
                  markers="d", scale=.75, ci=None)

    # Improve the legend
    #handles, labels = ax.get_legend_handles_labels()
    #ax.legend(handles[3:], labels[3:], title="gradients",
    #          handletextpad=0, columnspacing=1,
    #          loc="lower right", ncol=3, frameon=True)

# %%
# Sort the values
mean_values = [(column, float(df_highest_melt[df_highest_melt['pos'] == column].mean())) for column in df_highest['pos'].unique()]
mean_values.sort(key = lambda x : (x[1]))

sorter = [pos_value for (pos_value, mean) in mean_values]

df_melt_sorted = df_highest_melt.set_index('pos')
df_melt_sorted = df_melt_sorted.loc[sorter]
df_melt_sorted['pos'] = df_melt_sorted.index

# %%
with sns.axes_style("whitegrid"):
    f, ax = plt.subplots(figsize=(15, 8))
    # Initialize the figure
    #f, ax = plt.subplots()
    sns.despine(bottom=True, left=True)

    # Show each observation with a scatterplot
    sns.stripplot(x="value", y="pos", hue="variable",
                  data=df_melt_sorted, dodge=True, alpha=.25, zorder=1)

    # Show the conditional means, aligning each pointplot in the
    # center of the strips by adjusting the width allotted to each
    # category (.8 by default) by the number of hue levels
    sns.pointplot(x="value", y="pos", hue="variable",
                  data=df_melt_sorted, dodge=.4,
                  join=False, palette="dark",
                  markers="d", scale=.75, ci=None)


'''
with sns.axes_style("whitegrid"):
    f, ax = plt.subplots(figsize=(25, 16))
    ax = sns.violinplot(x="pos", y="value", #hue="variable",
                        data=df_highest_melt, 
                        palette="muted", 
                        #split=True,
                        inner="quartile",
                        bw=.2)
'''
# Out:
# '\nwith sns.axes_style("whitegrid"):\n    f, ax = plt.subplots(figsize=(25, 16))\n    ax = sns.violinplot(x="pos", y="value", #hue="variable",\n                        data=df_highest_melt, \n                        palette="muted", \n                        #split=True,\n                        inner="quartile",\n                        bw=.2)\n'

# %% [markdown]
# # Stats

# %%
from scipy import stats 
import pylab

# %%
a = df[df['pos'] == 'PROPN']['occ_scaled']

# %%
stats.ttest_1samp(a, 0, nan_policy='propagate', alternative='two-sided')

# %%
a.mean()

# %%
a = df[df['pos'] == 'NOUN']['ig']
b = df[df['pos'] == 'PUNCT']['ig']

# %%
stats.ttest_ind(a, b)
# Out:
# Ttest_indResult(statistic=0.1830259072759495, pvalue=0.8547969848004465)

# %%
plt.hist(a, bins=40, alpha=.5)
plt.hist(b, bins=40, alpha=.5)
# Out:
# (array([  2.,   0.,   0.,   0.,   0.,   0.,   0.,   4.,   1.,   2.,   1.,
#           1.,   4.,   8.,  12.,  22.,  32.,  44.,  62.,  91., 127., 112.,
#         108., 104.,  73.,  53.,  32.,  21.,  20.,  12.,   9.,   6.,   2.,
#           2.,   0.,   0.,   1.,   0.,   0.,   1.]),
#  array([-0.69967725, -0.66743049, -0.63518374, -0.60293698, -0.57069023,
#         -0.53844348, -0.50619672, -0.47394997, -0.44170321, -0.40945646,
#         -0.3772097 , -0.34496295, -0.3127162 , -0.28046944, -0.24822269,
#         -0.21597593, -0.18372918, -0.15148242, -0.11923567, -0.08698892,
#         -0.05474216, -0.02249541,  0.00975135,  0.0419981 ,  0.07424485,
#          0.10649161,  0.13873836,  0.17098512,  0.20323187,  0.23547863,
#          0.26772538,  0.29997213,  0.33221889,  0.36446564,  0.3967124 ,
#          0.42895915,  0.46120591,  0.49345266,  0.52569941,  0.55794617,
#          0.59019292]),
#  <BarContainer object of 40 artists>)

# %%
stats.probplot(a, dist="norm", plot=pylab)
pylab.show()
