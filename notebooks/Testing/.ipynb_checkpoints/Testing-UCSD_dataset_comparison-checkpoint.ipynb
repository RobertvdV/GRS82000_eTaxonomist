# %%
import numpy as np
import pandas as pd
import torch
import pickle
import re
from itertools import chain
from collections import Counter
import collections
import torch.nn as nn
from bs4 import BeautifulSoup
from bs4.element import Comment
import glob
import random
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import DistilBertTokenizer, DistilBertModel
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler, Dataset, random_split
from tqdm import tqdm
import time
import sys
import spacy
from selenium import webdriver

# Load spacy, disable all but senticizer
#nlp = spacy.load("en_core_web_trf") # does not work with .oov_
nlp = spacy.load("en_core_web_lg")

sys.path.insert(0, '../src/models/')
sys.path.insert(0, '../src/features/')

from predict_model import loadBERT
from predict_model import SpanPredictor as classify
from build_features import text_cleaner, DuckDuckGo_Java, Bing_HTML, colorize_prediction

# %matplotlib inline
# Out:
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
model = loadBERT("../models/", 'saved_weights_inf_FIXED_boot_beta80.pt')
tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
bert = DistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# CPU Success
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Birds used in the CUB dataset

# %%
# Open the text file
location = "../data/external/CUB_200_2011/CUB_200_2011/classes.txt"
with open(location) as f:
    lines = f.readlines()

# %%
# Init regex
regex = r'\d+\s\d+\.'
# Clean the list
CUB = [re.sub(regex, '', line).rstrip().replace('_', ' ') for line in lines]

# %%
# Read the BOWO list to compare names
# Read all html locations
BOWO_folder_list = glob.glob('../data/raw/BOW/*')
# Clean the lists
BOWO = [bird[16:] for bird in BOWO_folder_list]

# %%
# Intersect common names
birds_list = list(set(CUB) & set(BOWO))
# Random sample so the CUB is about 5%
birds_list += random.sample(list(set(BOWO) - set(CUB)), len(birds_list) * 19)

# %% [markdown]
# ### BOW HTMLS
# Open the Birds of the Worlds HTMLS that correspond to the UCB dataset and get the descriptions out using the trained classifier.

# %%
# Rejoin the location
birds_location = ['../data/raw/BOW/' + bird for bird in birds_list]

# %%
# Init dict for storage
birds_dict = collections.defaultdict(list)

for bird_loc in tqdm(birds_location[0:]):
    # Get the name
    BIRD = bird_loc[16:]
    # Check the amount of account
    if len(glob.glob(bird_loc + '/*')) > 1:
        # Construct the HTML
        HTML = bird_loc + '/Appearance.html'
    else:
        HTML = bird_loc + '/Introduction.html'
    # Open the HTML
    with open(HTML) as f:
        # Structure it
        soup = BeautifulSoup(f, 'html.parser')
        # Get all spans
        spans = [span for span in soup.find_all('p') 
                 if not 'fig' in span.text]
        for span in spans:
            # Remove double whitespace
            # Clean citations with a nested expression
            text = re.sub(r"\s+", " ", span.text)
            text = re.sub(r'\(\d+?\w\)', '###', text)
            text = re.sub(r'\([^)]*\)', '', text)
            # Replace ; with . to help the sentecizer
            text = text.replace(';', '.')
            # NLP
            doc = nlp(text)
            for sent in doc.sents:    
                # Skip short sents
                if len(sent) <= 4:
                    continue
                # Check amount of non-english
                non_eng = [token.is_oov for token in sent].count(True)
                # Skip if the ratio is above .2
                if non_eng > 0 and non_eng / len(sent) > .2:
                    continue
                # Also skip if the non-eng is large
                if non_eng > 8:
                    continue
                # Check classification
                if classify(sent.text, model=model):
                    birds_dict[BIRD].append(sent.text)

# %%
counts = [len(values) for values in birds_dict.values()]

# %%
# Dump the file into a pickle
with open('../data/description/04_TRAIN_0-2210_BIRDS.pkl', 'wb') as f:
    pickle.dump(birds_dict, f)

# %% [markdown]
# # Train a Model

# %%
birds_dict = pickle.load(open('../data/description/04_TRAIN_0-2210_BIRDS.pkl', 'rb'))

# %%
# Define the model
class BERT(nn.Module):
    def __init__(self, bert):
        super(BERT, self).__init__()

        # Distil Bert model
        self.bert = bert
        ## Additional layers
        # Dropout layer
        self.dropout = nn.Dropout(0.1)
        # Relu 
        self.relu =  nn.ReLU()
        # Linear I 
        self.fc1 = nn.Linear(768, 512)
        # Linear II (Out)
        self.fc2 = nn.Linear(512, 2210) # Some species where lost
        # Softmax
        self.softmax = nn.LogSoftmax(dim=1)


    # Forward pass
    def forward(self, **kwargs):
        # Pass data trough bert and extract 
        cls_hs = self.bert(**kwargs)
        # Extract hidden state
        hidden_state = cls_hs.last_hidden_state
        # Only first is needed for classification
        pooler = hidden_state[:, 0]
        # Dense layer 1        
        x = self.fc1(pooler)
        # ReLU activation
        x = self.relu(x)
        # Drop out
        x = self.dropout(x)
        # Dense layer 2
        x = self.fc2(x)
        # Activation
        x = self.softmax(x)

        return x

# %%
# Load the entire model
model = BERT(bert)

# Load pretrained model (colab)
try:
    try:
        model_save_name = 'saved_weights_CUB.pt'
        path = F"/content/gdrive/My Drive/{model_save_name}"
        model.load_state_dict(torch.load(path))
        print('Google Success')

    except:
        model_save_name = 'saved_weights_CUB.pt'
        path = "../models/" + model_save_name
        model.load_state_dict(torch.load(path, map_location=torch.device('cpu')))
        print('Local Success')
except:
    print('No pretrained model found.')

# Push the model to GPU (if available)
model = model.to(device)
model.eval()
model.zero_grad()
# Out:
# Local Success

# %% [markdown]
# # Interpretability

# %%
from IPython.display import display, HTML
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from captum.attr import visualization as viz
from captum.attr import IntegratedGradients, LayerConductance, LayerIntegratedGradients
from captum.attr import configure_interpretable_embedding_layer, remove_interpretable_embedding_layer
from captum.attr import Occlusion
from spacy import displacy

nlp = spacy.load("en_core_web_trf")

# %%
# Set seeds
torch.manual_seed(333)
np.random.seed(333)

# %% [markdown]
# ### Functions used for determining interpretability

# %%
# Modify the prediction output and define a custom forward
def predict(inputs):
    return model(input_ids=inputs, attention_mask=attention_mask)[0]

def custom_forward(inputs):
    preds = predict(inputs)
    return torch.exp(preds)

# Tokenize functions
def construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id):

    text_ids = tokenizer.encode(text, add_special_tokens=False)
    # construct input token ids
    input_ids = [cls_token_id] + text_ids + [sep_token_id]
    # construct reference token ids 
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(text_ids) + [sep_token_id]

    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(text_ids)

def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)# * -1
    return token_type_ids, ref_token_type_ids

def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids
    
def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)

# Summarize and vis functions
def summarize_attributions_ig(attributions):
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    return attributions

def summarize_attributions_occ(attributions):
    return attributions.sum(axis=0)

def token_to_words(attribution, tokens):
    
    words = []
    attributes = []

    for attribute, word in zip(attribution, tokens):

        attribute = attribute.cpu().detach().numpy()
        if word == '[CLS]' or word == '[SEP]':
            words.append(word)
            attributes.append([attribute])
        elif not word.startswith('##'):
            words.append(word)
            attributes.append([attribute])
        elif word.startswith('##'):
            words[-1] += word.strip('##')
            attributes[-1] = np.append(attributes[-1], attribute)

    attribution = [np.sum(mean) for mean in attributes]
    return attribution, words

def colorize(attribution, tokens):
    
    template = """  
    <mark class="entity" style="
    background: {}; 
    padding: 0.4em 0.0em; 
    margin: 0.0em; 
    line-height: 2; 
    border-radius: 0.0em;
    ">{}<span style="
    font-size: 0.8em; 
    font-weight: bold; 
    line-height: 1; 
    border-radius: 0.0em;   
    text-align-last:center;
    vertical-align: middle;
    margin-left: 0rem;
    "></span></mark>
    """

    colored_string = ''
    normalized_and_mapped = matplotlib.cm.ScalarMappable(cmap=matplotlib.cm.Greens).to_rgba(attribution[1:-1])
    for idx, (word, color) in enumerate(zip(tokens[1:-1], normalized_and_mapped)):
        
        word = word + ' '
        color = matplotlib.colors.rgb2hex(color[:3])
        #if word.strip() == '[CLS]' or word.strip() == '[SEP]': 
        #    color = '#ffffff'
        #print(color)
        colored_string += template.format(color, word)

    return colored_string

# %%
ref_token_id = tokenizer.pad_token_id # A token used for generating token reference
sep_token_id = tokenizer.sep_token_id # A token used as a separator between question and text and it is also added to the end of the text.
cls_token_id = tokenizer.cls_token_id # A token used for prepending to the concatenated question-text word sequence

# %%
# Methods
lig = LayerIntegratedGradients(custom_forward, model.bert.embeddings)
occ = Occlusion(custom_forward)

# %% [markdown]
# ### Single Test Example

# %%
text = 'Medium-sized auk, plumage dark blackish-brown in summer .'

# %%
input_ids, ref_input_ids, sep_id = construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id)
token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, sep_id)
position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
attention_mask = construct_attention_mask(input_ids)

indices = input_ids[0].detach().tolist()
all_tokens = tokenizer.convert_ids_to_tokens(indices)

# %%
attribution_occ = occ.attribute(inputs=input_ids, 
                                sliding_window_shapes=(4,), 
                                strides=1, 
                                baselines=None, 
                                target=None, 
                                additional_forward_args=None, 
                                perturbations_per_eval=1, 
                                show_progress=False)

# %%
# Sum the matrices
attributions_occ_sum = summarize_attributions_occ(attribution_occ)
# Token to words
# Words are the same in this case
attributions_occ_words, words = token_to_words(attributions_occ_sum, all_tokens)

# %%
# OCC
string = colorize(attributions_occ_words, words)
display(HTML(string))
# Out:
#
#     <mark class="entity" style="
#     background: #f1faee;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">medium <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #daf0d4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">sized <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ebf7e7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">auk <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7cc87c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumage <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #6bc072;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">dark <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #19833e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">blackish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e8f6e3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cfecc9;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">brown <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #48ae60;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">in <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #6bc072;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">summer <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #7cc87c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>

# %%
plt.plot(attributions_occ_words[1:-1])

# %%
def occlude(text):
    # Global BERT mask
    global attention_mask
    # Tokenize and prepare 
    input_ids, ref_input_ids, sep_id = construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id)
    token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, sep_id)
    position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
    attention_mask = construct_attention_mask(input_ids)
    # Detach in case the model is on GPU
    indices = input_ids[0].detach().tolist()
    all_tokens = tokenizer.convert_ids_to_tokens(indices)
    # Get occlusion values
    attributions_occ = occ.attribute(inputs=input_ids, 
                                    sliding_window_shapes=tuple([4,]), 
                                    strides=1, 
                                    baselines=None, 
                                    target=None, 
                                    additional_forward_args=None, 
                                    perturbations_per_eval=1, 
                                    show_progress=False)
    # Sum the matrices
    attributions_occ_sum = summarize_attributions_occ(attributions_occ)
    # Extract the words
    attributions_occ_words, words = token_to_words(attributions_occ_sum, all_tokens)
    # NLP (Skip tokens)
    doc = nlp(' '.join(words[1:-1]))
    # Init list
    PoS = []
    # Loop over the tokens
    for token, occ_att in zip(doc, attributions_occ_words[1:-1]):
        # Append to list
        PoS.append((token.text, token.pos_, token.dep_,  occ_att))
    
    return PoS

# %% [markdown]
# ### Part of Speech

# %%
text_list = birds_dict[birds_list[0]]

# %%
Pos_list = [occlude(text) for text in tqdm(text_list[0:20])]
# Out:
# 100%|███████████████████████████████████████████| 20/20 [00:30<00:00,  1.50s/it]

# %%
for sentence in Pos_list[0:20]:
    words = [item[0] for item in sentence]
    attribution_occlus = [item[3] for item in sentence]
    string = colorize(attribution_occlus, words)
    display(HTML(string))
    print('\n')
# Out:
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">. <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">pusillus <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f1faee;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">very <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e7f6e2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">little <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e7f6e3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c7e9c0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">very <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #eff9eb;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">small <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d2edcc;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">< <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ecf8e8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">dim <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #58b668;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">smallest <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f0f9ec;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">alcid <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #006227;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #0a7633;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">total <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #1c8540;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">length <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #248c46;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">12 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2f974e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #1c8540;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">14 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #006d2c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">cm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #157f3b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #087432;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">wingspan <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #077331;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">33 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2c944c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #127c39;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">36 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2e964d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">cm <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2f974e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #137d39;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">mean <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #0d7836;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">adult <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #005120;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">mass <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">about <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #016e2d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">85 <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mar
#
#     <mark class="entity" style="
#     background: #006027;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">' <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #005321;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">breeding <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #60ba6c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumage <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">underparts <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ecf8e8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">strikingly <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #329b51;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">variable <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #218944;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #1c8540;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">from <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #208843;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">unmarked <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #268e47;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">white <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2a924a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #17813d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">through <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #127c39;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">spotted <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #067230;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">intermediates <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #228a44;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #107a37;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">to <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #03702e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">entirely <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #077331;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">blackish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #006428;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">gray <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #005f26;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">except <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #0a7633;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">for <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-ali
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">dark <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ceecc8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">gray <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">white <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">patches <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">of <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">variable <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ceecc8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">extent <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #88ce87;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">on <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">scapulars <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d7efd1;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">winter <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e7f6e3;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #65bd6f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">upperparts <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b5e1ae;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">mostly <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b4e1ad;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">blackish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a4da9e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #dcf2d7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">facial <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #d5efcf;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">ornaments <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #a2d99c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">reduced <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #8ed08b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">with <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #4eb264;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">white <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3ba458;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">facial <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumes <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #bce4b5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">mostly <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ccebc6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">lacking <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b5e1ae;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b4e1ad;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">bill <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b8e3b2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">blackish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #dff3da;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f2faf0;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#
#     <mark class="entity" style="
#     background: #42ab5d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #75c477;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">adults <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #66bd6f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">in <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #55b567;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">summer <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #0a7633;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">resemble <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #37a055;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">breeding <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3fa85b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumage <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #218944;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">adults <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #005f26;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">but <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #37a055;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">have <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">duller <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e2f4dd;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">ornaments <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2c944c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">are <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #1e8741;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">darker <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #05712f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">in <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #278f48;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">overall <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2c944c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumage <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #248c46;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">color <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2b934b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #39a257;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margi
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">sexually <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">monomorphic <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">in <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ceecc8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumage <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">external <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">measurements <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00682a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">except <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">bill <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #1a843f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">is <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">slightly <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #5db96b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">but <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ceecc8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">significantly <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #aedea7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">deeper <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">in <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ceecc8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">males <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #37a055;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">similar <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">to <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">basic <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #37a055;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">- <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">plumaged <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #37a055;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">adult <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
# ...
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">gray <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">wings <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #4bb062;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">blackish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #73c476;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">gray <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #208843;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #157f3b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">nape <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #157f3b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #238b45;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">lores <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2f984f;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #3ea75a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">back <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #43ac5e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #147e3a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">rump <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #2a924a;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #006428;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">remiges <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #03702e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #19833e;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">rectrices <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #46ae60;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">, <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #46ae60;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">and <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #73c476;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">wing <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">coverts <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #18823d;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">dark <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #78c679;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">neutral <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">gray <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #0b7734;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">to <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #16803c;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">blackish <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></
#
#     <mark class="entity" style="
#     background: #c1e6ba;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">thin <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #cdecc7;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">pale <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #b7e2b1;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">line <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #c1e6ba;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">formed <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #daf0d4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">by <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e3f4de;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">short <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #e1f3dc;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">white <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #dbf1d6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">feathers <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #daf0d4;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">extends <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #005723;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">posteriorly <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ddf2d8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">from <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #ddf2d8;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">below <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f7fcf5;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">eye <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #f5fbf2;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">onto <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #00441b;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">auricular <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>
#
#     <mark class="entity" style="
#     background: #dbf1d6;
#     padding: 0.4em 0.0em;
#     margin: 0.0em;
#     line-height: 2;
#     border-radius: 0.0em;
#     ">region <span style="
#     font-size: 0.8em;
#     font-weight: bold;
#     line-height: 1;
#     border-radius: 0.0em;
#     text-align-last:center;
#     vertical-align: middle;
#     margin-left: 0rem;
#     "></span></mark>

# %%
# Flatten the list
flat_list = []
for idx, sublist in enumerate(Pos_list):
    for item in sublist:
        flat_list.append((idx, item[0], item[1], item[2], item[3]))
# Create DF        
df = pd.DataFrame(flat_list, columns=['Sentence', 'Word', 'PoS', 'Dep', 'Occlusion'])
# Melt the DF
df_melt = df.melt(id_vars=['PoS'], value_vars=['Occlusion'])

# %%
with sns.axes_style("whitegrid"):
    f, ax = plt.subplots(figsize=(15, 8))
    sns.despine(bottom=True, left=True)

    # Show each observation with a scatterplot
    sns.stripplot(x="value", y="PoS",
                  data=df_melt, dodge=True, alpha=.25, zorder=1)

    # Show the conditional means, aligning each pointplot in the
    # center of the strips by adjusting the width allotted to each
    # category (.8 by default) by the number of hue levels
    sns.pointplot(x="value", y="PoS",
                  data=df_melt, dodge=.4,
                  join=False, palette="dark",
                  markers="o", scale=.75, ci=None)

# %%
description_BOW_dict = collections.defaultdict(list)
species = birds_list[0]

for idx in tqdm(df['Sentence'].unique()):

    parent = ''

    # Sort the sentence
    index = df[(df['Sentence'] == idx) & (df['PoS'] == 'NOUN')]['Occlusion'].sort_values(ascending=False).index
    
    # SKIP NO NOUNS FOR NOUN
    if len(index) == 0:
        continue
    
    # Extract the noun
    NOUN = df.iloc[index, ].iloc[0, ]['Word']
    # Nlp the sentence
    doc = nlp(text_list[idx])
    # Find the subtree of the word
    for token in doc:
        if token.text.lower() == NOUN:
            # Extract the subtree
            span = doc[token.left_edge.i : token.right_edge.i + 1]
    # Extract ancestor if subtree does not exist
    if len(span) == 1:
        # Extract first
        parent = next(span[0].ancestors)

    if parent:
        #print(parent.text, span.text)
        description_BOW_dict[species].append(parent.text + ' ' + span.text)
    else:
        #print(span.text)
        description_BOW_dict[species].append(span.text)
# Out:
# 100%|███████████████████████████████████████████| 20/20 [00:02<00:00,  9.64it/s]

# %%
description_BOW_dict
# Out:
# defaultdict(list,
#             {'Least Auklet': [' L. pusillus very little, very small < dim.',
#               'mean adult mass about 85 g.',
#               'links of plumage color to age and social status',
#               'on scapulars',
#               'white facial plumes',
#               'breeding plumage adults',
#               'is bill',
#               'basic-plumaged adult',
#               'highly worn and tattered remiges',
#               'on scapulars',
#               'Auklet Parakeet',
#               'identical Sexes',
#               'Definitive Plumage acquired at Second Basic and Alternate Plumages.',
#               'fleecy down',
#               'Crown nape',
#               'blackish brown',
#               'throat, breast and abdomen',
#               'sides wings',
#               'blackish neutral gray',
#               'A thin pale line formed by short  white feathers']})

# %% [markdown]
# # Get Annotations

# %%
# Open the text file
location = "../data/external/CUB_200_2011/attributes.txt"
with open(location) as f:
    lines = f.readlines()

# %%
attribute_list = []

# Create a DF with attributes
for line in lines:
    line = line.strip()
    attributes = line.split()[1].split('::')
    part = attributes[0]
    adjective = attributes[1]
    attribute_list.append((part, adjective))
    
# Create DF        
df_attributes = pd.DataFrame(attribute_list, columns=['Part', 'Adj'])
# Reset the index
df_attributes.index = np.arange(1, len(df_attributes)+1)

# %%
# Open the text file
location = "../data/external/CUB_200_2011/CUB_200_2011/attributes/image_attribute_labels.txt"
with open(location) as f:
    lines = f.readlines()
# Open the text file
location = "../data/external/CUB_200_2011/CUB_200_2011/images.txt"
with open(location) as f:
    img_ids = f.readlines()

# %%
# Create DF will all present parts
CUB_dict = collections.defaultdict(list)
# Loop over lines
for line in tqdm(lines):
    data = line.split()
    # Skip non present
    if not int(data[2]):
        continue
    # Otherwise append
    #print(CUB[int(img_ids[int(data[0])].split()[1][0:3]) - 1], data)
    CUB_dict[CUB[int(img_ids[int(data[0])-1].split()[1][0:3]) - 1]].append((df_attributes.loc[int(data[1]), ][0], df_attributes.loc[int(data[1]), ][1]))
# Out:
# 100%|██████████████████████████████| 3677856/3677856 [01:36<00:00, 38305.44it/s]

# %%
# Drop duplicates
for bird in CUB_dict.keys():
    CUB_dict[bird] = list(set(CUB_dict[bird]))

# %%
description_CUB_dict = collections.defaultdict(list)
# Rewrite the sentence
for (part, adjective) in CUB_dict[birds_list[0]]:
    description_CUB_dict[birds_list[0]].append(part.lstrip('has_').replace('_', ' ') + ' ' + adjective)

# %% [markdown]
# # Similarity

# %%
from build_features import similarity_matrix as vector_values
from sklearn.metrics.pairwise import cosine_similarity

# %%
vv_BOW = vector_values(description_BOW_dict[birds_list[0]][0:10])

# %%
vv_CUB = vector_values(description_CUB_dict[birds_list[0]][0:10])

# %%
matrix = cosine_similarity(vv_BOW, vv_CUB)

# %%
# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(10, 10))
    ax = sns.heatmap(matrix, 
                     #mask=mask, 
                     square=True,
                     annot=True,
                     cbar=False,
                     #cmap='Spectral_r', 
                     cmap=cmap,
                     linewidths=.5,)
    
#ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha="right", fontsize=11)
#ax.set_yticklabels(ax.get_yticklabels(), rotation=0, ha="right", fontsize=11)


#f.suptitle('Similarity Matrix', fontsize=13)
#f.savefig('similarity_matrix.pdf', format='pdf', dpi=1200, bbox_inches='tight')

# %%
print(description_BOW_dict[birds_list[0]][4])
print(description_CUB_dict[birds_list[0]][5])
# Out:
# white facial plumes
# wing pattern spotted

# %%
sents[34]

# %%
sents[36]

# %%
matrix

# %%
description_BOW_dict[birds_list[0]][0:15]
