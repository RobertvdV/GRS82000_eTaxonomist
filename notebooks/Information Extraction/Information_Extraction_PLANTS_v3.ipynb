# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup
from matplotlib.colors import is_color_like as color_check
import requests
import random
import pickle
import re
import spacy
nlp = spacy.load('en_core_web_trf')
from spacy import displacy
import collections
from collections import Counter
from tqdm.notebook import tqdm as tqdm_notebook
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from transformers import DistilBertTokenizer, DistilBertModel, logging
from matplotlib.figure import Figure
from matplotlib import cm
import matplotlib.colors as colors
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/gp/hp50s5114x52591qbdhn43xm0000gn/T/ipykernel_21949/1276596951.py in <module>
#      14 import pickle
#      15 import re
# ---> 16 import spacy
#      17 nlp = spacy.load('en_core_web_trf')
#      18 from spacy import displacy
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/spacy/__init__.py in <module>
#       9
#      10 # These are imported as part of the API
# ---> 11 from thinc.api import prefer_gpu, require_gpu, require_cpu  # noqa: F401
#      12 from thinc.api import Config
#      13
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/thinc/api.py in <module>
#       1 from .config import Config, registry, ConfigValidationError
# ----> 2 from .initializers import normal_init, uniform_init, glorot_uniform_init, zero_init
#       3 from .initializers import configure_normal_init
#       4 from .loss import CategoricalCrossentropy, L2Distance, CosineDistance
#       5 from .loss import SequenceCategoricalCrossentropy
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/thinc/initializers.py in <module>
#       2 import numpy
#       3
# ----> 4 from .backends import Ops
#       5 from .config import registry
#       6 from .types import FloatsXd, Shape
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/thinc/backends/__init__.py in <module>
#       5 import threading
#       6
# ----> 7 from .ops import Ops
#       8 from .cupy_ops import CupyOps, has_cupy
#       9 from .numpy_ops import NumpyOps
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/thinc/backends/ops.py in <module>
#       8 from ..types import FloatsXd, Ints1d, Ints2d, Ints3d, Ints4d, IntsXd, _Floats
#       9 from ..types import DeviceTypes, Generator, Padded, Batchable, SizedGenerator
# ---> 10 from ..util import get_array_module, is_xp_array, to_numpy
#      11
#      12
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/thinc/util.py in <module>
#      25
#      26 try:  # pragma: no cover
# ---> 27     import torch
#      28     from torch import tensor
#      29     import torch.utils.dlpack
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/torch/__init__.py in <module>
#     194     # See Note [Global dependencies]
#     195     if USE_GLOBAL_DEPS:
# --> 196         _load_global_deps()
#     197     from torch._C import *  # noqa: F403
#     198
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/site-packages/torch/__init__.py in _load_global_deps()
#     147     lib_path = os.path.join(os.path.dirname(here), 'lib', lib_name)
#     148
# --> 149     ctypes.CDLL(lib_path, mode=ctypes.RTLD_GLOBAL)
#     150
#     151
#
# /usr/local/anaconda3/envs/DL/lib/python3.8/ctypes/__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371
#     372         if handle is None:
# --> 373             self._handle = _dlopen(self._name, mode)
#     374         else:
#     375             self._handle = handle
#
# KeyboardInterrupt:

# %%
# URL
URL = 'https://en.wikipedia.org/wiki/Glossary_of_plant_morphology'
# Get the page
page = requests.get(URL, timeout=5)
soup = BeautifulSoup(page.content, "lxml", from_encoding="iso-8859-1")   

glossary = collections.defaultdict(list)
# Find all H4 
for chapter in soup.find_all('h4')[0:]:
    # Clean
    chapter_text = chapter.text.rstrip('[edit]')
    # Find all siblings
    for sibling in chapter.find_next_siblings():
        # Find the parent
        for parent in sibling.find_previous_sibling('h4'):
            # Only append if correspond to current chapter
            if parent.text == chapter_text:
                if 'â' in sibling.text:
                    for tag in sibling.find_all('li'):
                        candidates = tag.text.split('â')[0]
                        candidates = candidates.split('/')
                        for candidate in candidates:
                            glossary[chapter_text.lower()].append(candidate.strip().lower())  
                            
glossary['leaves'] += [
    'glume', 'surface', 'margin',
    'leaves', 'auricles', 'spatheole',
    'ovate', 'lanceolate',
]

glossary['basic flower parts'] += [
    'floret', 'awn',
    'pod', 'lobe', 
    'capitulum', 'capitula', # unkown
    'legume', 'calyx', 'flowerhead'
]
glossary['inflorescences'] += [
    'spikelets', 'lemma', 'racemes',
    'axis', 'cluster', 
]
glossary['leaves'] += [
    'rhachilla',
    'needles',
]

glossary['other parts'] += [
    'apex', 'culm', 'tube',
    'palea', 'crown', 'canopy',
    'base', 'callus', 'hair',
    'anther', 'tuberculate', 'cone',
    'shoot', 'gland',

]

glossary['plant property'] += [
    'tree', 'shrub', 'plant',
    'life-span', 'life', 'span',
    'bloom-time', 'species', 'wood', 'timber',
    'color', 'colour', 
    
]

glossary['stems'] += [
    'branchlet', 
    
]

# %%
glossary.keys()
# Out:
# dict_keys(['morphology', 'roots', 'stems', 'buds', 'leaves', 'basic flower parts', 'inflorescences', 'insertion of floral parts', 'union of flower parts', 'flower sexuality and presence of floral parts', 'flower symmetry', 'terms for fruits', 'fruit types', 'pteridophytes', 'bryophytes', 'other parts', 'plant property'])

# %%
compounds = [
    'fertile', 'sterile',
    'male', 'female', 'bisexual',
    'basal', 'developed', 
    'primary', 'secondary', 'main',
    'upper', 'lower', 'greater', 'dorsal', 'alternate', 'lesser', 'apex', 'outer',
    'central', 'outermost', 'outer', 'inner', 'uppermost', 'median', 'dorsal', 'central', 'lateral',
    'young', 'mature', 'individual', 
    'opposite', 
]

rubbish = [
    '.', ',', '-', '..', '...',
]

measurements = [
    'mm', 'cm', 'm', 'km',
    'milimeter', 'centimeter', 'meter', 'kilometer',
    'milimetre', 'centimetre', 'metre', 'kilometre',
    'inch', 'foot', 'yard', 'mile',
    'wide', 'long', 'broad', 'tall',
    'length', 'form',
]

# %%
def compound_reconstructor(token, doc):
    if token.i == 0:
        trait = token
    elif doc[token.i - 1].pos_ == 'DET':
        trait = token
    elif doc[token.i - 3].dep_ == 'compound':
        trait = doc[token.i - 3: token.i + 1]
    elif doc[token.i - 3].text.lower() in compounds or doc[token.i - 3].lemma_.lower() in compounds:
        trait = doc[token.i - 3: token.i + 1]
    elif doc[token.i - 2].dep_ == 'compound':
        trait = doc[token.i - 2: token.i + 1]
    elif doc[token.i - 2].text.lower() in compounds or doc[token.i - 3].lemma_.lower() in compounds:
        trait = doc[token.i - 2: token.i + 1]
    elif doc[token.i - 1].dep_ == 'compound':
        trait = doc[token.i - 1: token.i + 1]
    elif doc[token.i - 1].text.lower() in compounds or doc[token.i - 3].lemma_.lower() in compounds:
        trait = doc[token.i - 1: token.i + 1]
    else:
        trait = token
    if ','  in trait.lemma_:
        trait = token
    return trait.lemma_    

def check_existance(t, doc):
    
    if t.i + 1 < len(doc) and doc[t.i + 1].lemma_ == '-':
        return None
    # Check prep
    single = next((key for key, value in glossary.items() if t.lemma_.lower() in value), None)
    multi = next((key for key, value in glossary.items() if t.text.lower() in value), None)
    if single:
        return single
    elif multi:
        return multi
    else:
        return None

def text_preparation(species, text):
    
    cleaners = [(r'(?<!\d)\.(?!\d)', ' '),
                (r'\s×\s', ' times '),
                #(r'\xa0', ' '),
                (r'\s+c\s+', ' '),
                (r'â\x80\x93', ' to '),
                (r'\xa0', ' '),
                (r'\x97', ''),
                (r'\s{2,}', ' ')]
    
    species_parts = species.split()
    candidates = [' '.join(species_parts[:idx+1]) for idx, _ in enumerate(species_parts)]
    candidates += [
        f'{species_parts[0][0]}. {species_parts[1]}'
    ]
    candidates.reverse()
    for candidate in candidates:
        try:
            text = re.sub(candidate, 'the species', text)
        except:
            continue # Skip species with brackets for now
    for (cleaner, replacement) in cleaners:
        text = re.sub(cleaner, replacement, text)    
    text = f'{text.strip()}.'
    
    return text.capitalize()


def extract_modifiers(t, doc):
    if t.text.lower() not in compounds:
        if t.dep_ in ['amod', 'nummod', 'appos', 'acl','prep', 'conj']:
            return doc[t.left_edge.i : t.right_edge.i + 1]
    
        
def create_relation(t):
    relation = ''
    if t in measurements or list(set(t.split()) & set(measurements)):
        relation = 'measures'  #'measurement'
    elif t.isdigit():
        relation = 'has number'
    elif color_check(t) or color_check(t.split()[-1]) or color_check(t.split('-')[-1]):
        relation = 'has color'
    else:
        relation = 'is' # Property
        
    return relation
        
def clean_object(t):
    objects = ''
    chunk_1 = 'a'
    chunk_2 = 'b'
    indices = [idx for idx, tok in enumerate(t) if tok.text == ',' or tok.text == 'and']
    
    try:
        for idx in indices:
            chunk_1 = next(t[idx - 1].ancestors).text
            chunk_2 = next(t[idx + 1].ancestors).text
    except:
        pass
    
    #print(chunk_1, chunk_2)
    if chunk_1 != chunk_2:
        if t.root.pos_ == 'NOUN' and t.root.lemma_ not in measurements:
            objects = t.root.lemma_
        else:
            if len(t) > 1:
                objects =  t.text
            elif t.root.pos_ == 'VERB':
                objects = t.text
            else:
                objects = t.lemma_

        objects =  re.split(',| and | or | with ', objects)
        
    else:
        objects = [t.text]
    return [obj.strip() for obj in objects if obj if obj not in rubbish]

def extract_verb(t, doc):
    if t.dep_  == 'nsubj':
        return next((parent for parent in t.ancestors if parent.pos_ == 'VERB' or parent.pos_ == 'AUX'), None)

def extract_verbal_modifier(t, doc):
    if t.text.lower() not in compounds:
        if child.dep_ in ["acomp", "dobj", "prep",]:
            return doc[child.left_edge.i : child.right_edge.i + 1]    
    
def create_main_triples(part, trait, obj):
    triples = []
    triples.append(('species', 'has main part', part.lower()))
    triples.append((part.lower(), f'has part', trait.lower()))
    for o in obj:
        rel = create_relation(o)
        triples.append((trait.lower(), rel.lower(), o.lower()))
    return triples

def create_sub_triples(sub, obj):
    triples = []
    for o in obj:
        rel = create_relation(o)
        triples.append((sub.lower(), rel.lower(), o.lower()))
    return triples

def noun_check(t):
    if t.root.pos_ == 'NOUN' and t.root.lemma_ not in measurements and not color_check(t.root.lemma_):
        return True
    else:
        return False

# %%
data = pickle.load(open('../../data/PlantNet/descriptions_raw.pkl', 'rb'))
#data = pickle.load(open('../../data/description/04_TRAIN_0000000-0014557_PLANTS.pkl', 'rb'))

# %%
#data = {
#    'Test Tree':[
#        'The green leaves with sharp edge and 10 mm wide.',
#    ]
#}

# %%
descriptions = collections.defaultdict(list)

for species in tqdm_notebook(list(data.keys())[0:1]):
    for idx, text in enumerate(data[species][0:10]):
        #print(text)
        triples = []
        text = text_preparation(species, text)
        doc = nlp(text)
        
        # TEMP ESCAPE
        try:
            if doc[-2].text in rubbish and doc[-3].text in rubbish:
                continue
            spaces = [t for t in doc if t.pos_ == 'SPACE']
            if len(spaces) > 1 and 'species' in doc.text.lower():
                continue
            if doc[-1].text in ['..', '...']:
                continue
        except:
            pass

        
        for t in doc:

            if t.pos_ == 'NOUN' or t.pos_ == 'PROPN' or t.pos_ == 'PRON':
                if t.dep_ == 'compound':
                    continue
                part = check_existance(t, doc)
                if part: 
                    # Trait
                    trait = compound_reconstructor(t, doc)
                    ## ADJs and NOUNs
                    for child in t.children:
                        obj_tok  = extract_modifiers(child, doc)
                        if obj_tok:
                            obj = clean_object(obj_tok)
                            triples += create_main_triples(part, trait, obj)
                            # modifiers of NOUNS
                            if noun_check(obj_tok):
                                for child in obj_tok.root.children:
                                    obj_tok = extract_modifiers(child, doc)
                                    if obj_tok:
                                        obj_new = clean_object(obj_tok)
                                        triples += create_sub_triples(obj[0], obj_new)
                                        
                    ## VERBs
                    verb = extract_verb(t, doc)
                    if verb:
                        for child in verb.children:
                            obj_tok  = extract_verbal_modifier(child, doc)
                            if obj_tok:
                                obj = clean_object(obj_tok)
                                triples += create_main_triples(part, trait, obj)
                            
                        
        print(text)
        print(idx, triples)
        print('\n')
        descriptions[species] += triples
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Shrub or tree.
# 0 [('species', 'has main part', 'plant property'), ('plant property', 'has part', 'shrub'), ('shrub', 'is', 'tree')]
#
#
# Shrub, tree.
# 1 [('species', 'has main part', 'plant property'), ('plant property', 'has part', 'shrub'), ('shrub', 'is', ', tree')]
#
#
# Branches grayish brown or dark reddish brown, glabrous, short shoots of young plants often thorn-tipped.
# 2 [('species', 'has main part', 'stems'), ('stems', 'has part', 'branch'), ('branch', 'has color', 'grayish brown'), ('branch', 'has color', 'dark reddish brown'), ('species', 'has main part', 'stems'), ('stems', 'has part', 'branch'), ('branch', 'is', 'glabrous, short shoots of young plants'), ('glabrous, short shoots of young plants', 'is', 'glabrous'), ('glabrous, short shoots of young plants', 'is', 'short'), ('glabrous, short shoots of young plants', 'is', 'of young plants'), ('species', 'has main part', 'other parts'), ('other parts', 'has part', 'shoot'), ('shoot', 'is', 'glabrous'), ('species', 'has main part', 'other parts'), ('other parts', 'has part', 'shoot'), ('shoot', 'is', 'short'), ('species', 'has main part', 'other parts'), ('other parts', 'has part', 'shoot'), ('shoot', 'is', 'of young plants')]
#
#
# Flowers: in umbel-like racemes or corymbs, calyx with tube turbinate or globose, accrescent, petals 5, broadly oblong or obovate, white, sep , oct fruit a pome, â± turbinate, up to â± 10 mm long, mesocarp fleshy-juicy with grit cells, seeds black or brownish black.
# 3 [('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'flower'), ('flower', 'is', 'in umbel-like racemes'), ('flower', 'is', 'corymbs'), ('flower', 'is', 'calyx'), ('flower', 'is', 'tube turbinate'), ('flower', 'is', 'globose'), ('flower', 'is', 'accrescent'), ('flower', 'is', 'petals 5'), ('flower', 'is', 'broadly oblong'), ('flower', 'is', 'obovate'), ('flower', 'has color', 'white'), ('flower', 'is', 'sep'), ('flower', 'is', 'oct fruit a pome'), ('flower', 'is', 'â± turbinate'), ('flower', 'measures', 'up to â± 10 mm long'), ('flower', 'is', 'mesocarp fleshy-juicy'), ('flower', 'is', 'grit cells'), ('flower', 'has color', 'seeds black'), ('flower', 'has color', 'brownish black'), ('species', 'has main part', 'inflorescences'), ('inflorescences', 'has part', 'raceme'), ('raceme', 'is', 'umbel-like'), ('species', 'has main part', 'inflorescences'), ('inflorescences', 'has part', 'raceme'), ('raceme', 'is', 'corymb'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'is', 'with tube turbinate'), ('calyx', 'is', 'globose'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'is', 'accrescent'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'is', 'petal'), ('petal', 'has number', '5'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'is', 'broadly oblong'), ('calyx', 'is', 'obovate'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'has color', 'white'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'is', 'sep'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'calyx'), ('calyx', 'is', 'fruit'), ('fruit', 'is', 'pome'), ('fruit', 'is', 'turbinate'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'petal'), ('petal', 'has number', '5'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'fruit'), ('fruit', 'is', 'pome'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'fruit'), ('fruit', 'is', 'turbinate'), ('turbinate', 'measures', 'up to â± 10 mm long'), ('species', 'has main part', 'terms for fruits'), ('terms for fruits', 'has part', 'mesocarp'), ('mesocarp', 'is', 'fleshy-juicy'), ('mesocarp', 'is', 'grit cells'), ('species', 'has main part', 'terms for fruits'), ('terms for fruits', 'has part', 'mesocarp'), ('mesocarp', 'is', 'seed'), ('seed', 'has color', 'black'), ('seed', 'has color', 'brownish black'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'seed'), ('seed', 'has color', 'black'), ('seed', 'has color', 'brownish black')]
#
#
# Leaves simple, petiolate, blade broadly elliptic, up to 90 mm long, apex acute, base rounded, margins serrate, glossy.
# 4 [('species', 'has main part', 'leaves'), ('leaves', 'has part', 'leave'), ('leave', 'is', 'simple'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'leave'), ('leave', 'is', 'petiolate'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'leave'), ('leave', 'is', 'blade'), ('blade', 'is', 'broadly elliptic'), ('blade', 'measures', 'up to 90 mm long'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'blade'), ('blade', 'is', 'broadly elliptic'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'blade'), ('blade', 'measures', 'up to 90 mm long')]
#
#
# Shrub or tree, up to 20 m high, deciduous.
# 5 [('species', 'has main part', 'plant property'), ('plant property', 'has part', 'shrub'), ('shrub', 'is', 'tree'), ('species', 'has main part', 'plant property'), ('plant property', 'has part', 'shrub'), ('shrub', 'measures', 'up to 20 m high'), ('species', 'has main part', 'plant property'), ('plant property', 'has part', 'shrub'), ('shrub', 'is', 'deciduous')]
#
#
# Stems often with lower branches spiny.
# 6 [('species', 'has main part', 'stems'), ('stems', 'has part', 'stem'), ('stem', 'is', 'with lower branches spiny')]
#
#
# Leaves: petiole 1.5 to 5 cm, slightly pubescent when young, blade ovate or suborbiculate to elliptic, 2 to 5 ã 1.5 to 2.5 cm, base broadly cuneate to almost rounded, margins obtusely serrate, serrulate, or crenulate, sometimes entire, ?densely ciliate when young?, apex acute or shortly acuminate, surfaces pubescent when young, glabrescent.
# 7 [('species', 'has main part', 'leaves'), ('leaves', 'has part', 'leave'), ('leave', 'is', ', apex acute or shortly acuminate'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'leave'), ('leave', 'is', 'surface'), ('surface', 'is', 'pubescent when young'), ('surface', 'is', ', glabrescent'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'petiole'), ('petiole', 'measures', '1.5 to 5 cm'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'petiole'), ('petiole', 'is', 'slightly pubescent when young'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'petiole'), ('petiole', 'is', 'blade'), ('blade', 'is', 'ovate'), ('blade', 'is', 'suborbiculate to elliptic'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'petiole'), ('petiole', 'measures', '2 to 5 ã 1.5 to 2.5 cm'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'petiole'), ('petiole', 'is', 'base'), ('base', 'is', 'broadly cuneate to almost rounded'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'blade'), ('blade', 'is', 'ovate'), ('blade', 'is', 'suborbiculate to elliptic'), ('species', 'has main part', 'other parts'), ('other parts', 'has part', 'base'), ('base', 'is', 'broadly cuneate to almost rounded'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'surface'), ('surface', 'is', 'pubescent when young'), ('species', 'has main part', 'leaves'), ('leaves', 'has part', 'surface'), ('surface', 'is', ', glabrescent')]
#
#
# Fruit color blushed green white.
# 8 [('species', 'has main part', 'plant property'), ('plant property', 'has part', 'fruit color'), ('fruit color', 'has color', 'white')]
#
#
# Deciduous, leaves serrate, buds with imbricate scales, flowers mainly white, stamens 20-30 with red or purple anthers, styles 2-5 withtwo ovules per locule, walls of locules are cartilaginous, seeds are black.
# 9 [('species', 'has main part', 'leaves'), ('leaves', 'has part', 'leave'), ('leave', 'is', 'cartilaginous'), ('species', 'has main part', 'stems'), ('stems', 'has part', 'bud'), ('bud', 'is', 'with imbricate scales'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'flower'), ('flower', 'is', 'deciduous'), ('flower', 'is', 'leaves serrate'), ('flower', 'is', 'buds'), ('flower', 'is', 'imbricate scales'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'flower'), ('flower', 'has color', 'mainly white'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'flower'), ('flower', 'is', 'stamen'), ('stamen', 'is', '20-30'), ('stamen', 'has color', 'with red'), ('stamen', 'is', 'purple anthers'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'flower'), ('flower', 'is', 'style'), ('style', 'is', '2-5'), ('style', 'is', 'withtwo ovules per locule'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'stamen'), ('stamen', 'is', '20-30'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'stamen'), ('stamen', 'has color', 'with red'), ('stamen', 'is', 'purple anthers'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'anther'), ('anther', 'has color', 'red'), ('anther', 'has color', 'purple'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'style'), ('style', 'is', '2-5'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'style'), ('style', 'is', 'withtwo ovules per locule'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'ovule'), ('ovule', 'is', 'per locule'), ('species', 'has main part', 'basic flower parts'), ('basic flower parts', 'has part', 'seed'), ('seed', 'has color', 'black')]

# %%
with open('../../data/PlantNet/descriptions_triples_raw_v3.pkl', 'wb') as f:
    pickle.dump(descriptions, f)

# %%
descriptions_text = collections.defaultdict(list)
descriptions_RDFs = collections.defaultdict(list)

for species in tqdm_notebook(descriptions.keys()):
    for (sub, rel, obj) in descriptions[species]:
        text = f'{sub} {rel} {obj}.'.capitalize()
        # Make sure order is the same
        if text not in descriptions_text[species]:
            descriptions_text[species].append(text)
            descriptions_RDFs[species].append((sub, rel, obj))
# Out:
#   0%|          | 0/228 [00:00<?, ?it/s]

# %%
with open('../../data/PlantNet/descriptions_triples_text_v3.pkl', 'wb') as f:
    pickle.dump(descriptions_text, f)      
    
with open('../../data/PlantNet/descriptions_triples_rdf_v3.pkl', 'wb') as f:
    pickle.dump(descriptions_RDFs, f)

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="15fc096e19bb4df4a200bb6e93860beb-0" class="displacy" width="3375" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Petals</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">white</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">pinkish,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">obovate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">lanceolate,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">7</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">ã</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">5</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">mm,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">pubescent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">basally,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">apex</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">obtuse.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PUNCT</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15fc096e19bb4df4a200bb6e93860beb-0-0" stroke-width="2px" d="M70,439.5 C70,2.0 2325.0,2.0 2325.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15fc096e19bb4df4a200bb6e93860beb-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15fc096e19bb4df4a200bb6e93860beb-0-1" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15fc096e19bb4df4a200bb6e93860beb-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M205.0,441.5 L213.0,429.5 197.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15fc096e19bb4df4a200bb6e93860beb-0-2" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15fc096e19bb4df4a200bb6e93860beb-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15fc096e19bb4df4a200bb6e93860beb-0-3" stroke-width="2px" d="M245,439.5 C245,264.5 560.0,264.5 560.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15fc096e19bb4df4a200bb6e93860beb-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M560.0,441.5 L568.0,429.5 552.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-15fc096e19bb4df4a200bb6e93860beb-0-4" stroke-width="2px" d="M70,439.5 C70,89.5 745.0,89.5 745.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-15fc096e19bb4df4a200bb6e93860beb-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M745.0,441.5 L753.0,429.5 737.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id

# %%
len(glossary.keys())

# %%
glossary['leaves']
