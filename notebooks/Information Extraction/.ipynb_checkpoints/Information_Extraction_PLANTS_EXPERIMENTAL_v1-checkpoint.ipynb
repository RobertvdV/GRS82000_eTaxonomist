# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
from tqdm.notebook import tqdm
from bs4 import BeautifulSoup
from matplotlib.colors import is_color_like as color_check
import requests
import random
import pickle
import re
import spacy
nlp = spacy.load('en_core_web_trf')
from spacy import displacy
import collections
from collections import Counter
from tqdm.notebook import tqdm as tqdm_notebook
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
from transformers import DistilBertTokenizer, DistilBertModel, logging
from matplotlib.figure import Figure
from matplotlib import cm
import matplotlib.colors as colors
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'

# %%
# URL
URL = 'https://en.wikipedia.org/wiki/Glossary_of_plant_morphology'
# Get the page
page = requests.get(URL, timeout=5)
soup = BeautifulSoup(page.content, "lxml", from_encoding="iso-8859-1")   

glossary = collections.defaultdict(list)
# Find all H4 
for chapter in soup.find_all('h4')[0:]:
    # Clean
    chapter_text = chapter.text.rstrip('[edit]')
    # Find all siblings
    for sibling in chapter.find_next_siblings():
        # Find the parent
        for parent in sibling.find_previous_sibling('h4'):
            # Only append if correspond to current chapter
            if parent.text == chapter_text:
                if 'â' in sibling.text:
                    for tag in sibling.find_all('li'):
                        candidates = tag.text.split('â')[0]
                        candidates = candidates.split('/')
                        for candidate in candidates:
                            glossary[chapter_text.lower()].append(candidate.strip().lower())  
                            
glossary['leaves'] += [
    'glume', 'surface', 'margin',
    'leaves', 'auricles', 'spatheole',
    'ovate', 'lanceolate',
]

glossary['basic flower parts'] += [
    'floret', 'awn',
    'pod', 'lobe', 
    'capitulum', 'capitula', # unkown
    'legume', 'calyx', 'flowerhead'
]
glossary['inflorescences'] += [
    'spikelets', 'lemma', 'racemes',
    'axis', 'cluster', 
]
glossary['leaves'] += [
    'rhachilla',
    'needles',
]

glossary['other parts'] += [
    'apex', 'culm', 'tube',
    'palea', 'crown', 'canopy',
    'base', 'callus', 'hair',
    'anther', 'tuberculate', 'cone',
    'shoot', 'gland',

]

glossary['plant property'] += [
    'tree', 'shrub', 'plant',
    'life-span', 'life', 'span',
    'bloom-time', 'species', 'wood', 'timber',
    'color', 'colour', 
    
]

glossary['stems'] += [
    'branchlet', 
    
]

# %%
glossary.keys()
# Out:
# dict_keys(['morphology', 'roots', 'stems', 'buds', 'leaves', 'basic flower parts', 'inflorescences', 'insertion of floral parts', 'union of flower parts', 'flower sexuality and presence of floral parts', 'flower symmetry', 'terms for fruits', 'fruit types', 'pteridophytes', 'bryophytes', 'other parts', 'plant property'])

# %%
compounds = [
    'fertile', 'sterile',
    'male', 'female', 'bisexual',
    'basal', 'developed', 
    'primary', 'secondary', 'main',
    'upper', 'lower', 'greater', 'dorsal', 'alternate', 'lesser', 'apex', 'outer',
    'central', 'outermost', 'outer', 'inner', 'uppermost', 'median', 'dorsal', 'central', 'lateral',
    'young', 'mature', 'individual', 
    'opposite', 
]

rubbish = [
    '.', ',', '-', '..', '...',
]

measurements = [
    'mm', 'cm', 'm', 'km',
    'milimeter', 'centimeter', 'meter', 'kilometer',
    'milimetre', 'centimetre', 'metre', 'kilometre',
    'inch', 'foot', 'yard', 'mile',
    'wide', 'long', 'broad', 'tall',
    'length', 'form',
]

# %%
#data = pickle.load(open('../../data/PlantNet/descriptions_raw.pkl', 'rb'))
data = pickle.load(open('../../data/description/04_TRAIN_0000000-0014557_PLANTS.pkl', 'rb'))

# %%
data = {
    'Test Tree':[
        '5 light-dark, slightly green leaves without any blue veins.',
        'The stems often with spiny lower branches',
        'Branches light-dark reddish brown or greenish purple or black.'
    ]
}

measurements_list = [
    'mm', 'cm', 'm', 'km',
    'milimeter', 'centimeter', 'meter', 'kilometer',
    'milimetre', 'centimetre', 'metre', 'kilometre',
    'inch', 'foot', 'yard', 'mile',
    'wide', 'long', 'broad', 'tall',
    #'length', 'form',
]

# %%
def text_preparation(species, text):
    
    cleaners = [(r'(?<!\d)\.(?!\d)', ' '),
                (r'\s×\s', ' times '),
                #(r'\xa0', ' '),
                (r'\s+c\s+', ' '),
                (r'â\x80\x93', ' to '),
                (r'\xa0', ' '),
                (r'\x97', ''),
                (r'\s{2,}', ' ')]
    
    species_parts = species.split()
    candidates = [' '.join(species_parts[:idx+1]) for idx, _ in enumerate(species_parts)]
    candidates += [
        f'{species_parts[0][0]}. {species_parts[1]}'
    ]
    candidates.reverse()
    for candidate in candidates:
        try:
            text = re.sub(candidate, 'the species', text)
        except:
            continue # Skip species with brackets for now
    for (cleaner, replacement) in cleaners:
        text = re.sub(cleaner, replacement, text)    
    text = f'{text.strip()}.'
    
    return text.capitalize()


def extract_modifiers(t, doc):
    # Init list
    modifiers = []
    #modifiets_dict = {}
    # Append to list
    for child in t.children:
        # Amods
        amod = amods(child, doc)
        modifiers += [amod]
        # amod of amods
        if amod:
            amod = extract_modifiers(amod, doc)
            modifiers += [amod]            
        # Measurements
        measurement = measurements(child, doc)
        if measurement:
            modifiers += [measurement]
            modifiers += [numbers_measurement(measurement, doc)]
        # Prepositions
        prep = prepositions(child, doc)
        if prep:
            modifiers += [prep]
            prep_info = prep_oject(prep, doc)
            modifiers += [[prep_info, extract_modifiers(prep_info, doc)]]
        # appositional modifiers
        appos = appositionals(child, doc)
        if appos:
            modifiers += [appos]
            modifiers += [extract_modifiers(appos, doc)]
        number = numbers(child, doc)
        if number:
            modifiers += [number]
        conjunction = conjunctions(child, doc)
        if conjunction:
            modifiers += [conjunction]
            modifiers += [extract_modifiers(conjunction, doc)]
        # Conjunctions # RECURSIVE NOT POSSIBLE?
        #for conjunction in child.children:
        #    if conjunction.dep_ == 'conj':
        #        modifiers += [conjunction]
        #        modifiers += [extract_modifiers(conjunction, doc)]

    return modifiers

def measurements(t, doc):
    # Find measurements
    if t.lemma_ in measurements_list:
        return t
        
def amods(t, doc):
    # Find amods
    if t.dep_ == 'amod':
        # Skip measurements
        if not measurements(t, doc):
            return t

def numbers_measurement(t, doc):
    for child in t.children:
        if child.lemma_ in measurements_list:
            return [child, [grandchild for grandchild in child.subtree
                            if grandchild.dep_ == 'nummod' and grandchild.pos_ == 'NUM'
                            or grandchild.dep_ == 'quantmod' and grandchild.pos_ == 'NUM']]

def prepositions(t, doc):
    if t.dep_ == 'prep':
        return t

def numbers(t, doc):
    if t.dep_ == 'nummod':
        return t
    
def prep_oject(t, doc):
    return next(child for child in t.children)

def appositionals(t, doc):
    if t.dep_ == 'appos':
        return t

def candidates(doc):
    return [t for t in doc
           if t.pos_ == 'NOUN' or t.pos_ == 'PROPN' or t.pos_ == 'PRON'
           and t.dep_ != 'compound']

def conjunctions(t, doc):
    if t.dep_ == 'conj':
        return t

# %%
descriptions = collections.defaultdict(list)

for species in tqdm_notebook(list(data.keys())[0:1]):
    for idx, text in enumerate(data[species][1:2]):
        doubles = []
        triples = []
        text = text_preparation(species, text)
        doc = nlp(text)
        
        
        for candidate in candidates(doc): 
            information = extract_modifiers(candidate, doc)
            
            #for info in infos:
            #    print(candidate, info)
            print(candidate, information)
                   
                    
        print(text)
        print(idx, triples)
        print('\n')
        descriptions[species] += triples
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Culms [None, long, [cm, [30, 60]]]
# cm [None, 60]
# Culms 30-60 cm long, 3-6 -noded.
# 0 []

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fcd497b12434402180389a215d39b18d-0" class="displacy" width="1625" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Branches</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">dark</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">reddish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">greenish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">purple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">black.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-0" stroke-width="2px" d="M245,264.5 C245,89.5 570.0,89.5 570.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,266.5 L237,254.5 253,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-1" stroke-width="2px" d="M420,264.5 C420,177.0 565.0,177.0 565.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,266.5 L412,254.5 428,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-2" stroke-width="2px" d="M70,264.5 C70,2.0 575.0,2.0 575.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,266.5 L583.0,254.5 567.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-3" stroke-width="2px" d="M595,264.5 C595,177.0 740.0,177.0 740.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M740.0,266.5 L748.0,254.5 732.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-4" stroke-width="2px" d="M945,264.5 C945,177.0 1090.0,177.0 1090.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,266.5 L937,254.5 953,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-5" stroke-width="2px" d="M595,264.5 C595,2.0 1100.0,2.0 1100.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1100.0,266.5 L1108.0,254.5 1092.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-6" stroke-width="2px" d="M1120,264.5 C1120,177.0 1265.0,177.0 1265.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1265.0,266.5 L1273.0,254.5 1257.0,254.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-fcd497b12434402180389a215d39b18d-0-7" stroke-width="2px" d="M1120,264.5 C1120,89.5 1445.0,89.5 1445.0,264.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-fcd497b12434402180389a215d39b18d-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1445.0,266.5 L1453.0,254.5 1437.0,254.5" fill="currentColor"/>
# </g>
# </svg></span>

# %%
def extract_modifiers(t, doc):
    # Init list
    modifiers_dict = {}
    
    # AMODS
    amods = extract_amods(t, doc)
    for child in amods:
        amods = extract_modifiers(child, doc)
        modifiers_dict[child] = amods
        
    # APPOS
    appos = extract_appos(t, doc)
    for child in appos:
        appos = extract_modifiers(child, doc)
        modifiers_dict[child] = appos
        
    # Preposition
    prep = extract_preps(t, doc)
    for child in prep:
        prep = extract_modifiers(child, doc)
        modifiers_dict[child] = prep
    
    # Preposition Objects
    prep_objs = extract_prep_ojects(t, doc)
    for child in prep_objs:
        prep_objs = extract_modifiers(child, doc)
        modifiers_dict[child] = prep_objs
        
    # MEASUREMENTS
    measurements = extract_measurements(t, doc)
    for child in measurements:
        measurements = extract_modifiers(child, doc)
        modifiers_dict[child] = measurements 
        
    # MEASUREMENTS UNITS
    units = extract_units(t, doc)
    for child in units:
        units = extract_modifiers(child, doc)
        modifiers_dict[child] = units
     
    # MEASUREMENTS UNITS MAX
    units_max = extract_units_max(t, doc)
    for child in units_max:
        units_max = extract_modifiers(child, doc)
        modifiers_dict[child] = units_max
        
        # MEASUREMENTS UNITS MIN
        units_min = extract_units_min(child, doc)
        for child in units_min:
            units_min = extract_modifiers(child, doc)
            modifiers_dict[child] = units_min     
       
    return modifiers_dict

def extract_amods(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'amod'
           and tok.lemma_ not in measurements_list]

def extract_appos(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'appos'
           and tok.lemma_ not in measurements_list]

def extract_preps(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'prep'
           and tok.lemma_ not in measurements_list]

def extract_prep_ojects(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'pobj'
           and tok.lemma_ not in measurements_list]

def extract_measurements(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'amod'
           and tok.lemma_ in measurements_list]

def extract_units(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'npadvmod'
           and tok.lemma_ in measurements_list]

def extract_units_max(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'nummod']

def extract_units_min(t, doc):
    return [tok for tok in t.children if tok.dep_ == 'quantmod']

# %%
descriptions = collections.defaultdict(list)

for species in tqdm_notebook(list(data.keys())[0:1]):
    for idx, text in enumerate(data[species][4:5]):
        text = text_preparation(species, text)
        doc = nlp(text)
        
        
        for candidate in candidates(doc): 
            information = extract_modifiers(candidate, doc)
            print(information)
            
        
            for info in information.keys():
                print((candidate, info))
                for subinfo in information[info]:
                    print((info, subinfo))
                    for subsubinfo in information[info][subinfo]:
                        print((subinfo, subsubinfo))
            
                   
                    
        #print(text)
        #print(idx, triples)
        #print('\n')
        #descriptions[species] += triples
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# {}
# {flat: {}, wide: {long: {}, cm: {11: {}, 6: {}}, mm: {4: {}, 3: {}}}}
# (blades, flat)
# (blades, wide)
# (wide, long)
# (wide, cm)
# (cm, 11)
# (cm, 6)
# (wide, mm)
# (mm, 4)
# (mm, 3)
# {11: {}, 6: {}}
# (cm, 11)
# (cm, 6)
# {4: {}, 3: {}}
# (mm, 4)
# (mm, 3)

# %%
information
# Out:
# {}

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="021855bcc9eb4e47a379386ef89d0c52-0" class="displacy" width="2325" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Leaf-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">blades</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">flat,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">or</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">conduplicate,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">6-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">11</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">cm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">long,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">3-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">4</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">mm</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">wide.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADJ</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M380.0,441.5 L388.0,429.5 372.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-2" stroke-width="2px" d="M420,439.5 C420,352.0 555.0,352.0 555.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">cc</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M555.0,441.5 L563.0,429.5 547.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-3" stroke-width="2px" d="M420,439.5 C420,264.5 735.0,264.5 735.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">conj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M735.0,441.5 L743.0,429.5 727.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-4" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">quantmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,441.5 L937,429.5 953,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-5" stroke-width="2px" d="M1120,439.5 C1120,352.0 1255.0,352.0 1255.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1120,441.5 L1112,429.5 1128,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-6" stroke-width="2px" d="M1295,439.5 C1295,89.5 2145.0,89.5 2145.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">npadvmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,441.5 L1287,429.5 1303,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-021855bcc9eb4e47a379386ef89d0c52-0-7" stroke-width="2px" d="M1470,439.5 C1470,177.0 2140.0,177.0 2140.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-021855bcc9eb4e47a379386ef89d0c52-0-7" class="disp

# %%
information
# Out:
# {brown: {dark: {light: {}}, reddish: {}}}
